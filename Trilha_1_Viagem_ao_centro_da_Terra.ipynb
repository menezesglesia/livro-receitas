# %% [markdown]
# <a href="https://colab.research.google.com/github/menezesglesia/livro-receitas/blob/master/Trilha_1_Viagem_ao_centro_da_Terra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.request  

texto = []

for line in urllib.request.urlopen('https://www.gutenberg.org/cache/epub/18857/pg18857.txt'): 
    texto.append(line.decode('utf-8'))

for i in range(len(texto)):
    texto[i] = texto[i].lower() # para unicidade
    texto[i] = texto[i].replace('\n','')
    texto[i] = texto[i].replace('[','')
    texto[i] = texto[i].replace(']','')
    texto[i] = texto[i].replace('.','')
    texto[i] = texto[i].replace('...','')
    texto[i] = texto[i].replace(':','')
    texto[i] = texto[i].replace('-','')
    texto[i] = texto[i].replace('--','')
    texto[i] = texto[i].replace(',','')
    texto[i] = texto[i].replace(';','')
    texto[i] = texto[i].replace('(','')
    texto[i] = texto[i].replace(')','')
    texto[i] = texto[i].replace('?','')
    texto[i] = texto[i].replace('!','')
    texto[i] = texto[i].replace('"','')
    texto[i] = texto[i].replace('\'','') # elimina ' e "

# %%
mydict = {}                             # crie um dicionário vazio

for line in texto:

  line = line.lower()                   # converte para lower
  words = line.split()                  # separa cada palavra
#  print(words)

  for word in words:                      # para cada palavra em words
    if word not in mydict.keys():         # se palavra não está no dicionário 
      mydict[word] = 1                    # acrescenta a word com o valor 1
    else:                                 # se a entrada já existe 
      mydict[word] =  mydict[word] + 1    # apenas soma 1 ao valor já existente

print(mydict)
# Out:
# {'\ufeffproject': 1, 'gutenbergs': 1, 'a': 1850, 'journey': 91, 'to': 2562, 'the': 5794, 'centre': 40, 'of': 3621, 'earth': 165, 'by': 449, 'jules': 5, 'verne': 5, 'this': 637, 'ebook': 10, 'is': 619, 'for': 414, 'use': 29, 'anyone': 10, 'anywhere': 3, 'at': 575, 'no': 329, 'cost': 4, 'and': 2280, 'with': 626, 'almost': 44, 'restrictions': 2, 'whatsoever': 2, 'you': 393, 'may': 88, 'copy': 12, 'it': 918, 'give': 53, 'away': 69, 'or': 271, 'reuse': 2, 'under': 101, 'terms': 21, 'project': 92, 'gutenberg': 31, 'license': 15, 'included': 3, 'online': 4, 'wwwgutenbergorg': 3, 'title': 1, 'author': 2, 'release': 2, 'date': 7, 'july': 8, '18': 3, '2006': 1, '#18857': 1, 'last': 122, 'updated': 2, 'december': 1, '27': 3, '2012': 1, 'language': 20, 'english': 16, '***': 6, 'start': 23, 'produced': 16, 'norm': 2, 'wolcott': 2, 'redactors': 1, 'note': 9, 'number': 17, 'v002': 1, 'in': 1428, 'taves': 1, 'michaluk': 1, 'numbering': 1, 'works': 38, 'first': 90, 'published': 4, 'england': 8, 'griffith': 1, 'farran': 1, '1871': 1, 'edition': 2, 'not': 557, 'translation': 3, 'all': 399, 'but': 426, 'complete': 13, 'rewrite': 1, 'novel': 5, 'portions': 5, 'added': 16, 'omitted': 2, 'names': 2, 'changed': 11, 'most': 112, 'reprinted': 1, 'version': 2, 'entered': 17, 'into': 171, 'reference': 2, 'purposes': 2, 'only': 132, 'better': 10, '_a': 1, 'interior': 60, 'earth_': 1, 'translated': 6, 'rev': 1, 'f': 1, 'malleson': 1, 'also': 19, 'available': 4, 'on': 472, 'table': 11, 'contents': 2, 'chapter': 89, '1': 5, 'my': 1286, 'uncle': 483, 'makes': 11, 'great': 170, 'discovery': 44, '2': 5, 'mysterious': 24, 'parchment': 13, '3': 7, 'an': 300, 'astounding': 6, '4': 8, 'we': 959, '5': 5, 'lessons': 4, 'climbing': 4, '6': 4, 'our': 503, 'voyage': 34, 'iceland': 48, '7': 3, 'conversation': 17, '8': 2, 'eiderdown': 7, 'hunteroff': 2, '9': 2, 'startwe': 2, 'meet': 13, 'adventures': 7, 'way': 117, '10': 2, 'traveling': 20, '11': 2, 'reach': 32, 'mount': 18, 'sneffelsthe': 2, 'reykir': 3, '12': 2, 'ascent': 7, 'sneffels': 49, '13': 2, 'shadow': 18, 'scartaris': 11, '14': 2, 'real': 25, 'commences': 2, '15': 2, 'continue': 12, 'descent': 23, '16': 2, 'eastern': 6, 'tunnel': 32, '17': 2, 'deeper': 8, 'deeperthe': 2, 'coal': 18, 'mine': 18, 'wrong': 11, 'road': 34, '19': 2, 'western': 8, 'gallerya': 2, 'new': 47, 'route': 11, '20': 2, 'water': 125, 'where': 85, 'bitter': 7, 'disappointment': 6, '21': 2, 'ocean': 45, '22': 2, 'sunday': 9, 'below': 37, 'ground': 15, '23': 2, 'alone': 22, '24': 2, 'lost': 60, '25': 2, 'whispering': 3, 'gallery': 48, '26': 2, 'rapid': 22, 'recovery': 2, 'central': 29, 'sea': 116, '28': 2, 'launching': 2, 'raft': 88, '29': 2, 'watersa': 3, '30': 3, 'terrific': 5, 'saurian': 3, 'combat': 7, '31': 2, 'monster': 19, '32': 2, 'battle': 5, 'elements': 7, '33': 2, 'reversed': 2, '34': 2, '35': 2, 'upon': 188, '36': 2, 'what': 290, '37': 2, 'dagger': 5, '38': 2, 'outletblasting': 2, 'rock': 68, '39': 2, 'explosion': 14, 'its': 187, 'results': 3, '40': 2, 'ape': 5, 'gigans': 6, '41': 2, 'hunger': 19, '42': 2, 'volcanic': 23, 'shaft': 20, '43': 3, 'daylight': 3, '44': 2, 'ended': 6, 'looking': 21, 'back': 76, 'that': 779, 'has': 94, 'occurred': 5, 'me': 332, 'since': 26, 'eventful': 1, 'day': 101, 'i': 2005, 'am': 70, 'scarcely': 46, 'able': 43, 'believe': 40, 'reality': 11, 'they': 113, 'were': 441, 'truly': 15, 'so': 210, 'wonderful': 20, 'even': 99, 'now': 232, 'bewildered': 5, 'when': 194, 'think': 62, 'them': 98, 'was': 1251, 'german': 7, 'having': 55, 'married': 3, 'mothers': 1, 'sister': 1, 'englishwoman': 1, 'being': 75, 'very': 231, 'much': 92, 'attached': 4, 'his': 541, 'fatherless': 1, 'nephew': 17, 'he': 572, 'invited': 2, 'study': 10, 'him': 171, 'home': 9, 'fatherland': 1, 'large': 28, 'town': 16, 'professor': 177, 'philosophy': 3, 'chemistry': 2, 'geology': 5, 'mineralogy': 5, 'many': 70, 'other': 121, 'ologies': 1, 'one': 264, 'after': 166, 'passing': 5, 'some': 213, 'hours': 57, 'laboratorymy': 1, 'absent': 4, 'timei': 2, ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

df = pd.DataFrame(mydict.items(),  columns=['word', 'count']).sort_values('count',ascending=False)
df = df[df['count'] > 90] # somente termos com mais de 4 ocorrências
#df = df.iloc[ np.int(len(df)/2) - 10 : np.int(len(df)/2) + 10 ] # para livros ou textos com muitos termos limita a um número mínimo de termos

plt.figure(figsize=(25,10))
mpl.style.use(['seaborn'])
sns.barplot(x=df.word,y=df['count'])
plt.xticks(rotation=90) 

plt.show()
